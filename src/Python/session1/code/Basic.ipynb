# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x= 10 
print(type(x))
# Out:
# <class 'int'>

# %%
Name = "Youssef"
Age = 20
CourseName = "Machine Learning Engineer Depi"
output = f"Hello, my name is {Name}, I am {Age} years old and I am a {CourseName}."
print(output)
# Out:
# Hello, my name is Youssef, I am 20 years old and I am a Machine Learning Engineer Depi.
