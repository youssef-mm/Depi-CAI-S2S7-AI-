# %%
list1 = [1,2,3,4, "Youssef", "MM", False,[1,2,3, "ML"]]
list1
# Out:
# [1, 2, 3, 4, 'Youssef', 'MM', False, [1, 2, 3, 'ML']]

# %%
list("YouMM")
# Out:
# ['Y', 'o', 'u', 'M', 'M']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
x = list2 = ["youmm", "MM", "ML"]
x.append("Youssef")
print(x)
print(type(x))
# Out:
# ['youmm', 'MM', 'ML', 'Youssef']
# <class 'list'>

# %%
list1 = ["depi", "R5", "ML"]
list2 = ["youmm", "MM", "ML"]
list1.extend(list2)
list1
# Out:
# ['depi', 'R5', 'ML', 'youmm', 'MM', 'ML']

# %%
list1 = ["depi", "R5", "ML"]
list2 = ["youmm", "MM", "ML"]
list3 = list1 + list2
print(list3)
# Out:
# ['depi', 'R5', 'ML', 'youmm', 'MM', 'ML']

# %%
#list
remove1 = input("enter the element you want to remove from the list: ")
input_list = ["amit","learning","python","ML","DS","DL"]
input_list.remove(remove1)
input_list
# Out:
# ['learning', 'python', 'ML', 'DS', 'DL']

# %%
#Tuple
name = ["name", "age"]
new_tuple = tuple(name)
print(new_tuple)
print(type(new_tuple))
# Out:
# ('name', 'age')
# <class 'tuple'>

# %%
#Set
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
#set

set1 = {"youssef","machineLearning","deepLearning","dataScience","youssef"}
print(type(set1))
set1
# Out:
# <class 'set'>
# {'dataScience', 'deepLearning', 'machineLearning', 'youssef'}

# %%
chatbot = {"name": "Youssef", "age": 25, "skills": ["ML", "DL", "DS"], "is_active": True, 
           "address": {"city": "Cairo", "country": "Egypt"}}
question = input("Enter the key you want to access: ").lower()
print(chatbot.get(question, "Key not found in the dictionary."))
# Out:
# Youssef

# %%
#calculator #add #subtract #multiply #divide
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -, *, /): ")
print(num1, operation, num2, "=", eval(str(num1) + operation + str(num2)))
# Out:
# 10.0 + 20.0 = 30.0
